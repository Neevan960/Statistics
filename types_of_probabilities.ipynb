# %% [markdown]
# ## Data
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 1.Types of Probabilities

# %%
print("Marginal Probabilities","\n")
P_No = 0.816
print("P(No): ",P_No)
P_Yes= 0.183  
print("P(Yes): ",P_Yes)
P_Young= 0.301 
print("P(Young) : ",P_Young)
P_Middle_aged = 0.690
print("P(Middle_aged) : ",P_Middle_aged)
P_Old = 0.008 
print("P(Old) : ",P_Old)
print("\n")
print("Joint Probabilities","\n")
P_No_and_Young = 0.224 
print("P(No and Young): ",P_No_and_Young)
P_No_and_Middle_aged = 0.586
print("P(No and Middle-aged): ",P_No_and_Middle_aged)
P_No_and_Old = 0.005
print("P(No and Old): ",P_No_and_Old)
P_Yes_and_Young = 0.076
print("P(Yes and Young) : ",P_Yes_and_Young)
P_Yes_and_Middle_aged = 0.103
print("P(Yes and Middle-aged): ",P_Yes_and_Middle_aged)
P_Yes_and_Old = 0.002
print("P(Yes and Old): ",P_Yes_and_Old)
print("\n")
print("Union Probabilities","\n")
P_No_or_Young =P_No+P_Young-P_No_and_Young
print("P(No or Young) : ",P_No_or_Young)
P_No_or_Middle_aged =P_No+P_Middle_aged-P_No_and_Middle_aged
print("P(No or Middle-aged) : ",P_No_or_Middle_aged)
P_No_or_Old = P_No + P_Old - P_No_and_Old
print("P(No or Old): ",P_No_or_Old)
P_Yes_or_Young = P_Yes+ P_Young- P_Yes_and_Young
print("P(Yes or Young) : ",P_Yes_or_Young)
P_Yes_or_Middle_aged = P_Yes + P_Middle_aged - P_Yes_and_Middle_aged
print("P(Yes or Middle-aged): ",P_Yes_or_Middle_aged)
P_Yes_or_Old = P_Yes + P_Old- P_Yes_and_Old
print("P(Yes or Old) : ",P_Yes_or_Old)
print("\n")
print("Conditional Probabilities","\n")
P_No_by_Young = P_No_and_Young/P_Young
print("P_No_by_Young: ",P_No_by_Young)
P_No_by_Middle_aged = P_No_and_Middle_aged/P_Middle_aged
print("P_No_by_Middle_aged : ",P_No_by_Middle_aged)
P_No_by_Old = P_No_and_Old/P_Old
print("P_No_by_Old : ",P_No_by_Old)
P_Yes_by_Young = P_Yes_and_Young/P_Young 
print("P_Yes_by_Young : ",P_Yes_by_Young)
P_Yes_by_Middle_aged = P_Yes_and_Middle_aged/P_Middle_aged
print("P_Yes_by_Middle_aged : ",P_Yes_by_Middle_aged)
P_Yes_by_Old = P_Yes_and_Old / P_Old
print("P_Yes_by_Old : ",P_Yes_by_Old)
# Out:
# Marginal Probabilities
#
# P(No):  0.816
# P(Yes):  0.183
# P(Young) :  0.301
# P(Middle_aged) :  0.69
# P(Old) :  0.008
#
#
# Joint Probabilities
#
# P(No and Young):  0.224
# P(No and Middle-aged):  0.586
# P(No and Old):  0.005
# P(Yes and Young) :  0.076
# P(Yes and Middle-aged):  0.103
# P(Yes and Old):  0.002
#
#
# Union Probabilities
#
# P(No or Young) :  0.893
# P(No or Middle-aged) :  0.9199999999999998
# P(No or Old):  0.819
# P(Yes or Young) :  0.408
# P(Yes or Middle-aged):  0.77
# P(Yes or Old) :  0.189
#
#
# Conditional Probabilities
#
# P_No_by_Young:  0.7441860465116279
# P_No_by_Middle_aged :  0.8492753623188406
# P_No_by_Old :  0.625
# P_Yes_by_Young :  0.25249169435215946
# P_Yes_by_Middle_aged :  0.1492753623188406
# P_Yes_by_Old :  0.25

# %% [markdown]
# ## 2. A builder markets houses through brokers and online. Builder has data that 60% of prospective buyers who know about his houses know it through brokers, and 40% know through online website. He also knows that out of prospective buyers contacted through brokers, 25% actually end up buying a house; and out of those through who knew through online medium 20% end up buying. Which one is more effective medium for the builder (broker or online)?

# %% [markdown]
# ![buy.jpg](attachment:buy.jpg)
#
# - Answer : Selling the houses through Broker is effective way to the Builder as the Probability of broker given by Buying is more than online given by Buying is more

# %% [markdown]
# ## 3. Let’s assume there is an HIV test that can identify HIV+ positive patients accurately 99% of the time, and also accurately has a negative result for 99% of HIV negative people. Here, only 0.3% of the overall population is HIV positive.
# ![image.png](attachment:image.png)
